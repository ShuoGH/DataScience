# %% [markdown]
# # Introduction
#
# ## Using Jupyter
#
# Jupyter is a front end to the [IPython](https://ipython.org) interactive shell, and offers IDE like features.  It is separated into two main types of cell: [Markdown](https://en.wikipedia.org/wiki/Markdown) cells (such as this one) which allows markdown or HTML code to be written, and code cells like the next one which can be run in real time.
#
# To execute code in a cell, press `Crtl` + `Enter`, click on the `[ > ]Run` button in the main menu, or press `Shift` + `Enter` if you wish to execute the code and then move on to a new cell (creating it if it does not already exist).
#
# ## Setup
#
# MongoDB is a NoSQL database, which has a core API in JavaScript, and a series of other APIs in different languages.  The one we are going to use is the Python API, [PyMongo](https://api.mongodb.com/python/current/).  MongoDB instance on your VM is already started by default.
#
# PyMongo is a package that contains tools to work with MongoDB from Python. We have installed it in the VM provided to you.

# %% [markdown]
# This imports the `MongoClient` class from the pymongo module, which we will use to deal with all our connections from.  We're connecting to our localhost, which is listening on port 27017. There are more options, the documentation for the formatting of the connection string is at https://docs.mongodb.com/manual/reference/connection-string/.

# %%
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017')

# %% [markdown]
# If you do not get any errors, you have confirmed PyMongo library has been successfully installed&configured in the VM. We will now check to see whether the connection is correct.  The following code calls a function which returns a list of all current databases.  If your Mongo instance is still empty, it should be something like `['admin', 'local']`.

# %%
client.list_database_names()
# Out:
# [u'local']

# %% [markdown]
# Next, we are going to create a database object `db`, which is a property of the `client` object.  MongoDB is schemaless, and so accessing a database like this will create the database if it does not already exist.
#
# A database can be accessed by using "dot" notation (i.e., `client.dbname`), or dictionary notation (i.e., `client['dbname']`).  This also applies to making collections
#
# Create a database called `test` in a variable called `db`.  Using that variable, create a collection called `test_collection` with a variable called `collection` as follows.  Run the code in the following cell (there should not be any output)

# %%
# Create database and collection objects for convenience
db = client.test
collection = db.test_collection

# %% [markdown]
# # Using MongoDB
#
# ## Inserting data
#
# MongoDB data is stored as BSON (binary JSON), which is essentially JSON with some additional optimisations, so the way to insert data is as a JSON object.  For Python, you can use a `dict` or a `list` for this, and then call either `insert_one` or `insert_many` on the collection.

# %%
# Create an object and insert into the `test_collection`
single_obj = {'name': 'Amber', 'star_sign': 'Capricorn', 'favourite_song': 'The Load-Out'}
collection.insert_one(single_obj)
single_obj_2 = {'name': 'Huw', 'star_sign': 'Libra', 'favourite_song': 'The masses against the classes'}
collection.insert_one(single_obj_2)
single_obj_3 = {'name': 'Robert', 'star_sign': 'Leo', 'favourite_song': 'Bad day'}
collection.insert_one(single_obj_3)

# %% [markdown]
# We will look at querying data in more detail below, but for now, to see whether the object got successfully inserted into the collection, run the code below.  This will always return the first instance which matches the query.  You will notice that even though we didn't specify `_id` one got added already.  This is a unique identifier for the document in the collection

# %%
collection.find_one() # returns a single document matching the query condition
# Out:
# {u'_id': ObjectId('5bdc50c45ccae901faa6050c'),
#  u'favourite_song': u'The Load-Out',
#  u'name': u'Amber',
#  u'star_sign': u'Capricorn'}

# %%
collection.find_one({'name':'Robert'})
# Out:
# {u'_id': ObjectId('5bdc50c45ccae901faa6050e'),
#  u'favourite_song': u'Bad day',
#  u'name': u'Robert',
#  u'star_sign': u'Leo'}

# %% [markdown]
# Remember, for MongoDB, you do not have to specify a schema or create a collection, it will be created automatically.  You don't need to keep to the same layout, but can have entirely different objects.  Consider the following:

# %%
from datetime import datetime
obj1 = {'Meaning of life': 42}
obj2 = {'ABC': 'DEF', 'time': datetime.now()}
collection.insert_one(obj1)
collection.insert_one(obj2)

# %% [markdown]
# We can also use the `insert_many`, which accepts a list of dicts.  In the cell below, create a list of dicts called `many_objects`, and call the `insert_many` function.  The code below that will iterate over all the documents in the database.

# %%
# YOUR CODE HERE
single_obj_4={"1":"one"}
single_obj_5={"2":"two"}
single_obj_6={"3":"three"}

many_objects=[single_obj4,single_obj_5,single_obj_6]
collection.insert_many(many_objects)


#See what has been inserted into the collection
for doc in collection.find():
    print(doc)
# Out:
# {u'favourite_song': u'The Load-Out', u'_id': ObjectId('5bdc50c45ccae901faa6050c'), u'name': u'Amber', u'star_sign': u'Capricorn'}
# {u'favourite_song': u'The masses against the classes', u'_id': ObjectId('5bdc50c45ccae901faa6050d'), u'name': u'Huw', u'star_sign': u'Libra'}
# {u'favourite_song': u'Bad day', u'_id': ObjectId('5bdc50c45ccae901faa6050e'), u'name': u'Robert', u'star_sign': u'Leo'}
# {u'Meaning of life': 42, u'_id': ObjectId('5bdc51205ccae901faa6050f')}
# {u'_id': ObjectId('5bdc51205ccae901faa60510'), u'ABC': u'DEF', u'time': datetime.datetime(2018, 11, 2, 13, 29, 4, 832000)}
# {u'favourite_song': u'The Load-Out', u'_id': ObjectId('5bdc583b5ccae901faa60511'), u'name': u'Amber', u'star_sign': u'Capricorn'}
# {u'favourite_song': u'The masses against the classes', u'_id': ObjectId('5bdc583b5ccae901faa60512'), u'name': u'Huw', u'star_sign': u'Libra'}
# {u'favourite_song': u'Bad day', u'_id': ObjectId('5bdc583b5ccae901faa60513'), u'name': u'Robert', u'star_sign': u'Leo'}
# {u'Meaning of life': 42, u'_id': ObjectId('5bdc58415ccae901faa60514')}
# {u'_id': ObjectId('5bdc58415ccae901faa60515'), u'ABC': u'DEF', u'time': datetime.datetime(2018, 11, 2, 13, 59, 29, 943000)}
# {u'1': u'one', u'_id': ObjectId('5bdc59465ccae901faa60516')}
# {u'2': u'two', u'_id': ObjectId('5bdc59465ccae901faa60517')}
# {u'3': u'three', u'_id': ObjectId('5bdc59465ccae901faa60518')}

# %% [markdown]
# ## Importing and querying data
#
# For this part of the exercise, we will use a sample dataset provided by Mongo  for a documentation tutorial.  The following cell runs the `mongoimport` command, which is a Unix command which comes with Mongo for importing data. We will need to run a bash command in the next cell first.  This uses the Jupyter \"magics\", and requires that the first line include `%%bash`. The code does the following:
#
# - Download the JSON file from the url, and save as ./primer-dataset.json
# - Import into the `test` database into the collection `restaurants` whilst dropping any collection which already exists from the file ./primer-dataset.json
# - Deletes the file.
#
#  Click on the following cell, and execute it:

# %%
# %%bash
# # Use wget to download the data
# wget https://raw.githubusercontent.com/mongodb/docs-assets/primer-dataset/primer-dataset.json
# # mongoimport is the Mongo command to import data.
# # It specifies the database, collection and format, and import file
# # --drop means it's going to drop any collection with the same name which already exists
# mongoimport --db test --collection restaurants --drop --file ./primer-dataset.json
# # Delete the JSON file we just downloaded
# rm ./primer-dataset.json
# Out:
# --2018-11-02 13:39:57--  https://raw.githubusercontent.com/mongodb/docs-assets/primer-dataset/primer-dataset.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101
#  11550K .......... .......... .......... .......... ......    100% 15.9M=0.7s
#
# 2018-11-02 13:39:58 (16.2 MB/s) - ‘primer-dataset.json’ saved [11874761/11874761]
#
# 2018-11-02T13:39:58.964+0000	connected to: localhost
# 2018-11-02T13:39:58.964+0000	dropping: test.restaurants
# 2018-11-02T13:40:00.592+0000	imported 25359 documents

# %% [markdown]
# Change the variable `collection` to refer to the new collection `restaurants`, and inspect the general format of the data by adding the code below to find the first record of the collection:

# %%
# YOUR CODE HERE
collection=db.restaurants
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'test'), u'restaurants')

# %%
for i in collection.find():
    print(i)
# Out:
# {u'cuisine': u'Bakery', u'borough': u'Bronx', u'name': u'Morris Park Bake Shop', u'restaurant_id': u'30075445', u'grades': [{u'date': datetime.datetime(2014, 3, 3, 0, 0), u'grade': u'A', u'score': 2}, {u'date': datetime.datetime(2013, 9, 11, 0, 0), u'grade': u'A', u'score': 6}, {u'date': datetime.datetime(2013, 1, 24, 0, 0), u'grade': u'A', u'score': 10}, {u'date': datetime.datetime(2011, 11, 23, 0, 0), u'grade': u'A', u'score': 9}, {u'date': datetime.datetime(2011, 3, 10, 0, 0), u'grade': u'B', u'score': 14}], u'address': {u'building': u'1007', u'street': u'Morris Park Ave', u'zipcode': u'10462', u'coord': [-73.856077, 40.848447]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3bf5')}
# {u'cuisine': u'Hamburgers', u'borough': u'Brooklyn', u'name': u"Wendy'S", u'restaurant_id': u'30112340', u'grades': [{u'date': datetime.datetime(2014, 12, 30, 0, 0), u'grade': u'A', u'score': 8}, {u'date': datetime.datetime(2014, 7, 1, 0, 0), u'grade': u'B', u'score': 23}, {u'date': datetime.datetime(2013, 4, 30, 0, 0), u'grade': u'A', u'score': 12}, {u'date': datetime.datetime(2012, 5, 8, 0, 0), u'grade': u'A', u'score': 12}], u'address': {u'building': u'469', u'street': u'Flatbush Avenue', u'zipcode': u'11225', u'coord': [-73.961704, 40.662942]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3bf6')}
# {u'cuisine': u'Irish', u'borough': u'Manhattan', u'name': u'Dj Reynolds Pub And Restaurant', u'restaurant_id': u'30191841', u'grades': [{u'date': datetime.datetime(2014, 9, 6, 0, 0), u'grade': u'A', u'score': 2}, {u'date': datetime.datetime(2013, 7, 22, 0, 0), u'grade': u'A', u'score': 11}, {u'date': datetime.datetime(2012, 7, 31, 0, 0), u'grade': u'A', u'score': 12}, {u'date': datetime.datetime(2011, 12, 29, 0, 0), u'grade': u'A', u'score': 12}], u'address': {u'building': u'351', u'street': u'West   57 Street', u'zipcode': u'10019', u'coord': [-73.98513559999999, 40.7676919]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3bf7')}
# {u'cuisine': u'American', u'borough': u'Brooklyn', u'name': u'Riviera Caterer', u'restaurant_id': u'40356018', u'grades': [{u'date': datetime.datetime(2014, 6, 10, 0, 0), u'grade': u'A', u'score': 5}, {u'date': datetime.datetime(2013, 6, 5, 0, 0), u'grade': u'A', u'score': 7}, {u'date': datetime.datetime(2012, 4, 13, 0, 0), u'grade': u'A', u'score': 12}, {u'date': datetime.datetime(2011, 10, 12, 0, 0), u'grade': u'A', u'score': 12}], u'address': {u'building': u'2780', u'street': u'Stillwell Avenue', u'zipcode': u'11224', u'coord': [-73.98241999999999, 40.579505]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3bf8')}
# {u'cuisine': u'Jewish/Kosher', u'borough': u'Queens', u'name': u'Tov Kosher Kitchen', u'restaurant_id': u'40356068', u'grades': [{u'date': datetime.datetime(2014, 11, 24, 0, 0), u'grade': u'Z', u'score': 20}, {u'date': datetime.datetime(2013, 1, 17, 0, 0), u'grade': u'A', u'score': 13}, {u'date': datetime.datetime(2012, 8, 2, 0, 0), u'grade': u'A', u'score': 13}, {u'date': datetime.datetime(2011, 12, 15, 0, 0), u'grade': u'B', u'score': 25}], u'address': {u'building': u'97-22', u'street': u'63 Road', u'zipcode': u'11374', u'coord': [-73.8601152, 40.7311739]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3bf9')}
# {u'cuisine': u'American', u'borough': u'Queens', u'name': u'Brunos On The Boulevard', u'restaurant_id': u'40356151', u'grades': [{u'date': datetime.datetime(2014, 11, 15, 0, 0), u'grade': u'Z', u'score': 38}, {u'date': datetime.datetime(2014, 5, 2, 0, 0), u'grade': u'A', u'score': 10}, {u'date': datetime.datetime(2013, 3, 2, 0, 0), u'grade': u'A', u'score': 7}, {u'date': datetime.datetime(2012, 2, 10, 0, 0), u'grade': u'A', u'score': 13}], u'address': {u'building': u'8825', u'street': u'Astoria Boulevard', u'zipcode': u'11369', u'coord': [-73.8803827, 40.7643124]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3
}, u'_id': ObjectId('5bdc53b03a4f0b44814f9f01')}
# {u'cuisine': u'Other', u'borough': u'Staten Island', u'name': u'Indian Oven', u'restaurant_id': u'50018994', u'grades': [], u'address': {u'building': u'461', u'street': u'Port Richmond Ave', u'zipcode': u'10302', u'coord': [-74.138492, 40.631136]}, u'_id': ObjectId('5bdc53b03a4f0b44814f9f02')}
# {u'cuisine': u'Other', u'borough': u'Brooklyn', u'name': u"Cold Press'D", u'restaurant_id': u'50018995', u'grades': [], u'address': {u'building': u'921', u'street': u'Cortelyou Rd', u'zipcode': u'11218', u'coord': [-73.9691347, 40.6389857]}, u'_id': ObjectId('5bdc53b03a4f0b44814f9f03')}

# %% [markdown]
# We saw the [`collection.find()`](https://api.mongodb.com/python/current/api/pymongo/collection.html#pymongo.collection.Collection.find) function earlier to return all the documents we inserted into our `test` collection.  Without any arguments, `find()` will return a cursor of all the available documents from in the collection.  To refine queries, however, the search can be filtered by the addition of a first parameter.
#
# The `filter` parameter is a dict, which searches for the documents where `key` = `value` where the dict is of the form `{key: value}`.  For example, to find all bakeries in the city, we would do the following query:
#
# **WARNING** Unlike the Mongo command line interface, if you try and print the output of a `find()` query, it will continue to output all results until it has finished.  This can cause the browser to crash, particularly if it is a particularly large query set.
#
# Using `find().count()` is a useful way of checking how many a result will return, and `find_one()` to see the general structure of a result. If you use `find()`, make sure you either include the `limit` argument, or have a counter or other condition to break out of your printing loop!

# %%
collection.find({'cuisine': 'Bakery'}).limit(5)    #what's this? should it be a cursor?

# %% [markdown]
# Noted, count() is deprecated in the MongoDb drivers compatible with the 4.0features, as a result, we should use countDocuments() in the following exercises. (for more information, check https://docs.mongodb.com/manual/reference/method/db.collection.count/ and http://api.mongodb.com/python/current/changelog.html)

# %%
collection.count_documents({'cuisine': 'Bakery'})
# Out:
# 691

# %% [markdown]
# A filter can have as many conditions as you like, and will assume that you are using an AND condition, unless you specify otherwise (as below).  In the cell below, write a query to return the number/count of all the establishments with a cuisine of `Hamburgers` in the borough of Manhattan.

# %%
# YOUR CODE HERE
# All establishments with: 
# * a cuisine of 'Hamburgers' 
# * in the borough of 'Manhattan
from pprint import pprint
a=collection.count_documents({'cuisine':'Hamburgers'})
b=collection.count_documents({'cuisine':'Hamburgers','borough':'Manhattan'})
print(a,b)

#n=0
for i in collection.find( {"$and": [{'cuisine':'Hamburgers'} , {'borough':'Manhattan'}]}):
    pprint(i)
#    n=n+1
 #   print(n)
#use this, you can find the data which satisfy the condition
# Out:
# (433, 124)
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3d1d'),
#  u'address': {u'building': u'427',
#               u'coord': [-73.9996841, 40.7543101],
#               u'street': u'10 Avenue',
#               u'zipcode': u'10001'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 11, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2012, 11, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2011, 11, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 6}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40370146'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3ddc'),
#  u'address': {u'building': u'1560',
#               u'coord': [-73.98527039999999, 40.7589099],
#               u'street': u'Broadway',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2014, 8, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2014, 2, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 9, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 2, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2012, 1, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40379897'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3eeb'),
#  u'address': {u'building': u'1345',
#               u'coord': [-73.9557858, 40.813575],
#               u'street': u'Amsterdam Avenue',
#               u'zipcode': u'10027'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 7, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 7, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 2, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2012, 8, 28, 0, 0),
#               u'grade': u'C',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 1, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2011, 9, 13, 0, 0),
#               u'grade': u'B',
#               u'score': 9}],
#  u'name': u"The Famous Jimbo'S Hamburger Palace",
#  u'restaurant_id': u'40390409'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3f1c'),
#  u'address': {u'building': u'809',
#               u'coord': [-73.9890844, 40.7483602],
#               u'street': u'6 Avenue',
#               u'zipcode': u'10001'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 7, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2014, 2, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2013, 8, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 8, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2011, 8, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40391659'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3f56'),
#  u'address': {u'building': u'335',
#               u'coord': [-73.9972555, 40.7476408],
#               u'street': u'8 Avenue',
#               u'zipcode': u'10001'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2014, 9, 23, 0, 0),
#               u'grade': u'C',
#               u'score': 2},
#              {u'date': datetime.datetime(2014, 4, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2013, 3, 15, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 10, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 5, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40393474'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f408a'),
#  u'address': {u'building': u'20922094',
#               u'coord': [-73.9475662, 40.8098915],
#               u'street': u'7Th Ave',
#               u'zipcode': u'10027'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2014, 1, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2012, 12, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2011, 12, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'White Castle',
#  u'restaurant_id': u'40399922'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f40c7'),
#  u'address': {u'building': u'351',
#               u'coord': [-73.9417015, 40.78800349999999],
#               u'street': u'East  103 Street',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 11, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 11, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 0},
#              {u'date': datetime.datetime(2011, 12, 1, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u'White Castle',
#  u'restaurant_id': u'40400962'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f40e9'),
#  u'address': {u'building': u'401',
#               u'coord': [-73.98403019999999, 40.7429936],
#               u'street': u'Park Avenue South',
#               u'zipcode': u'10016'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 6, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2014, 1, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 4, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 11, 30, 0, 0),
#               u'grade': u'C',
#               u'score': 44},
#              {u'date': datetime.datetime(2011, 11, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40401504'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4104'),
#  u'address': {u'building': u'237987',
#               u'coord': [-73.9419869, 40.8175016],
#               u'street': u'Adam Clayton Powell Boulevard',
#               u'zipcode': u'10030'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 9, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 5, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2012, 4, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2011, 12, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40401953'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4223'),
#  u'address': {u'building': u'766',
#               u'coord': [-73.988011, 40.76420299999999],
#               u'street': u'Ninth Avenue',
#               u'zipcode': u'10019'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2014, 3, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 7, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2013, 2, 19, 0, 0),
#               u'grade': u'B',
#               u'score': 15},
#              {u'date': datetime.datetime(2012, 5, 1, 0, 0),
#               u'grade': u'B',
#               u'score': 19},
#              {u'date': datetime.datetime(2011, 9, 27, 0, 0),
#               u'grade': u'B',
#               u'score': 17}],
#  u'name': u'Island Burgers And Shakes',
#  u'restaurant_id': u'40527001'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4231'),
#  u'address': {u'building': u'1211',
#               u'coord': [-73.9815467, 40.7584118],
#               u'street': u'Avenue Of The Americas',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 1, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 4, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 3, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 3, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u"Wendy'S",
#  u'restaurant_id': u'40529991'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f426f'),
#  u'address': {u'building': u'4040',
#               u'coord': [-73.9390066, 40.8427157],
#               u'street': u'Broadway',
#               u'zipcode': u'10032'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2013, 10, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 10, 1, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 3, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40538662'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f42c8'),
#  u'address': {u'building': u'4259',
#               u'coord': [-73.93614699999999, 40.8501658],
#               u'street': u'Broadway',
#               u'zipcode': u'10033'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2014, 6, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 5, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 5, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 1, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40548768'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f445b'),
#  u'address': {u'building': u'16',
#               u'coord': [-74.0124913, 40.704817],
#               u'street': u'Beaver Street',
#               u'zipcode': u'10004'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 2, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 7, 22, 0, 0),
#               u'grade': u'B',
#               u'score': 15},
#              {u'date': datetime.datetime(2012, 12, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 7, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2011, 7, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'40600619'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4479'),
#  u'address': {u'building': u'27',
#               u'coord': [-73.9893222, 40.7295826],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10003'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 6, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2013, 6, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2012, 6, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 2, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2011, 10, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2011, 6, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 13}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40603925'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4516'),
#  u'address': {u'building': u'130',
#               u'coord': [-73.9470784, 40.8081125],
#               u'street': u'West  125 Street',
#               u'zipcode': u'10027'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 7, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2014, 2, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 2, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 3, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2011, 11, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'40640500'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f45a1'),
#  u'address': {u'building': u'208',
#               u'coord': [-74.00503780000001, 40.72880809999999],
#               u'street': u'Varick Street',
#               u'zipcode': u'10014'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 3, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 2, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 9, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40668120'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4659'),
#  u'address': {u'building': u'525',
#               u'coord': [-73.9926363, 40.7538399],
#               u'street': u'8 Avenue',
#               u'zipcode': u'10018'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 3, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 3, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2012, 3, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 0},
#              {u'date': datetime.datetime(2011, 4, 1, 0, 0),
#               u'grade': u'A',
#               u'score': 2}],
#  u'name': u'White Castle',
#  u'restaurant_id': u'40705978'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f46a5'),
#  u'address': {u'building': u'18',
#               u'coord': [-73.98033749999999, 40.7529521],
#               u'street': u'East 42 Street',
#               u'zipcode': u'10017'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 7, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 7, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 7, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 3, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 0}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40719508'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4715'),
#  u'address': {u'building': u'102',
#               u'coord': [-73.9858807, 40.7264521],
#               u'street': u'1 Avenue',
#               u'zipcode': u'10009'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2014, 7, 21, 0, 0),
#               u'grade': u'B',
#               u'score': 18},
#              {u'date': datetime.datetime(2013, 11, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2013, 6, 14, 0, 0),
#               u'grade': u'B',
#               u'score': 22},
#              {u'date': datetime.datetime(2012, 10, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40733411'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4716'),
#  u'address': {u'building': u'724',
#               u'coord': [-73.9932841, 40.7291149],
#               u'street': u'Broadway',
#               u'zipcode': u'10003'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 4, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 7, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 8, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 2, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40733412'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4720'),
#  u'address': {u'building': u'735',
#               u'coord': [-73.98933509999999, 40.763422],
#               u'street': u'9 Avenue',
#               u'zipcode': u'10019'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 5, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 11, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 6, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 5, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2011, 12, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2011, 8, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 2}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40735151'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4740'),
#  u'address': {u'building': u'729',
#               u'coord': [-73.973793, 40.748161],
#               u'street': u'2 Avenue',
#               u'zipcode': u'10016'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2014, 6, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 12, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 11, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2011, 11, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40738247'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f47a5'),
#  u'address': {u'building': u'966',
#               u'coord': [-73.967455, 40.760891],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10022'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 4, 1, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 10, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 10, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 5, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2011, 12, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 2}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40751626'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f486a'),
#  u'address': {u'building': u'151',
#               u'coord': [-73.98952609999999, 40.7507917],
#               u'street': u'West   34 Street',
#               u'zipcode': u'10001'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2014, 2, 10, 0, 0),
#               u'grade': u'B',
#               u'score': 18},
#              {u'date': datetime.datetime(2013, 6, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 6},
#              {u'date': datetime.datetime(2012, 5, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u"Mcdonald'S (Macy'S 7Th Fl)",
#  u'restaurant_id': u'40799399'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4874'),
#  u'address': {u'building': u'160',
#               u'coord': [-74.00998369999999, 40.7093625],
#               u'street': u'Broadway',
#               u'zipcode': u'10038'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 2, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 8, 13, 0, 0),
#               u'grade': u'B',
#               u'score': 21},
#              {u'date': datetime.datetime(2013, 1, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2011, 12, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2011, 8, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2011, 3, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 4}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40800557'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4886'),
#  u'address': {u'building': u'1871',
#               u'coord': [-73.947161, 40.784705],
#               u'street': u'2 Avenue',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2013, 10, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 5, 31, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2012, 5, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'40804631'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f48be'),
#  u'address': {u'building': u'703705',
#               u'coord': [-73.94392189999999, 40.810025],
#               u'street': u'Lenox Avenue',
#               u'zipcode': u'10039'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 3, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 8, 8, 0, 0),
#               u'grade': u'B',
#               u'score': 20},
#              {u'date': datetime.datetime(2012, 12, 21, 0, 0),
#               u'grade': u'B',
#               u'score': 20},
#              {u'date': datetime.datetime(2012, 4, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u"Jimbo'S Hamburgers",
#  u'restaurant_id': u'40815136'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f49a5'),
#  u'address': {u'building': u'804',
#               u'coord': [-73.966993, 40.764309],
#               u'street': u'Lexington Avenue',
#               u'zipcode': u'10065'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 10, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2012, 9, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 4, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2011, 11, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u'Burger Heaven',
#  u'restaurant_id': u'40860020'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f49c2'),
#  u'address': {u'building': u'1419',
#               u'coord': [-73.93379130000001, 40.8492875],
#               u'street': u'St Nicholas Avenue',
#               u'zipcode': u'10033'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 7, 19, 0, 0),
#               u'grade': u'B',
#               u'score': 15},
#              {u'date': datetime.datetime(2014, 1, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 6, 17, 0, 0),
#               u'grade': u'B',
#               u'score': 15},
#              {u'date': datetime.datetime(2013, 1, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'40863935'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4a67'),
#  u'address': {u'building': u'2027',
#               u'coord': [-73.9378643, 40.8034962],
#               u'street': u'Lexington Avenue',
#               u'zipcode': u'10035'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 4, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 10, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 10, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 6},
#              {u'date': datetime.datetime(2012, 4, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2011, 11, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 13}],
#  u'name': u'Jimbos Hamburger Palace',
#  u'restaurant_id': u'40885326'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4b2a'),
#  u'address': {u'building': u'2048',
#               u'coord': [-73.9402489, 40.8358318],
#               u'street': u'Amsterdam Avenue',
#               u'zipcode': u'10032'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 4, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2013, 11, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 5, 24, 0, 0),
#               u'grade': u'B',
#               u'score': 17},
#              {u'date': datetime.datetime(2012, 12, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2011, 12, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2011, 6, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Jimbo'S Hamburger Palace",
#  u'restaurant_id': u'40923236'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4d4e'),
#  u'address': {u'building': u'1886',
#               u'coord': [-73.94579270000001, 40.7905455],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 8, 15, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 3, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 3, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'40989776'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4d56'),
#  u'address': {u'building': u'335',
#               u'coord': [-73.9847422, 40.747743],
#               u'street': u'5 Avenue',
#               u'zipcode': u'10016'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 5, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 11, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2013, 4, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 4, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2011, 11, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 4}],
#  u'name': u"Wendy'S",
#  u'restaurant_id': u'40990997'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4dc9'),
#  u'address': {u'building': u'972',
#               u'coord': [-92.72296209999999, 41.746136],
#               u'street': u'6 Avenue',
#               u'zipcode': u'10018'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 7, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 6},
#              {u'date': datetime.datetime(2014, 2, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 1, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 8, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 3, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41002547'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4f95'),
#  u'address': {u'building': u'1188',
#               u'coord': [-92.71942399999999, 41.7460966],
#               u'street': u'6 Avenue',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2014, 6, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 5, 15, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 10, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41050362'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f502c'),
#  u'address': {u'building': u'146',
#               u'coord': [-73.9865666, 40.7183138],
#               u'street': u'Delancey Street',
#               u'zipcode': u'10002'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2014, 4, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2013, 3, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 3, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41068780'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f5186'),
#  u'address': {u'building': u'106',
#               u'coord': [-74.0119117, 40.7096373],
#               u'street': u'Liberty Street',
#               u'zipcode': u'10006'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2014, 6, 27, 0, 0),
#               u'grade': u'B',
#               u'score': 23},
#              {u'date': datetime.datetime(2014, 1, 31, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 6, 4, 0, 0),
#               u'grade': u'B',
#               u'score': 18},
#              {u'date': datetime.datetime(2012, 12, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2011, 11, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41104489'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f5187'),
#  u'address': {u'building': u'401',
#               u'coord': [-73.98300449999999, 40.7499898],
#               u'street': u'Fifth Avenue',
#               u'zipcode': u'10016'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2014, 4, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 10, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 5, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 12, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2011, 12, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 13}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41104491'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f5188'),
#  u'address': {u'building': u'474',
#               u'coord': [-73.9899211, 40.7520443],
#               u'street': u'7 Avenue',
#               u'zipcode': u'10018'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 12, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 12, 7, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41104517'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f5189'),
#  u'address': {u'building': u'226',
#               u'coord': [-73.9530228, 40.7780962],
#               u'street': u'East   86 Street',
#               u'zipcode': u'10028'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2013, 11, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 4, 25, 0, 0),
#               u'grade': u'B',
#               u'score': 27},
#              {u'date': datetime.datetime(2012, 10, 10, 0, 0),
#               u'grade': u'B',
#               u'score': 16}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41104530'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f518a'),
#  u'address': {u'building': u'327',
#               u'coord': [-73.990914, 40.7580219],
#               u'street': u'West   42 Street',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 2, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 1, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 1, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 3}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41104540'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f518c'),
#  u'address': {u'building': u'1313',
#               u'coord': [-73.988152, 40.750155],
#               u'street': u'Broadway',
#               u'zipcode': u'10001'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2013, 12, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2012, 12, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 1, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u'Burger King',
#  u'restaurant_id': u'41104587'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f52a8'),
#  u'address': {u'building': u'678',
#               u'coord': [-92.72770670000001, 41.7461421],
#               u'street': u'6 Avenue',
#               u'zipcode': u'10010'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2014, 4, 4, 0, 0),
#               u'grade': u'C',
#               u'score': 40},
#              {u'date': datetime.datetime(2013, 1, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 1, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2011, 9, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u'New York Burger Co',
#  u'restaurant_id': u'41138498'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f5349'),
#  u'address': {u'building': u'112',
#               u'coord': [-73.9506998, 40.8021536],
#               u'street': u'West  116 Street',
#               u'zipcode': u'10026'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 4, 16, 0, 0),
#               u'grade': u'B',
#               u'score': 19},
#              {u'date': datetime.datetime(2013, 8, 9, 0, 0),
#               u'grade': u'B',
#               u'score': 26},
#              {u'date': datetime.datetime(2013, 2, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 1, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 2}],
#  u'name': u'Jumbos Hamburger',
#  u'restaurant_id': u'41153655'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f551a'),
#  u'address': {u'building': u'969',
#               u'coord': [-73.96490399999999, 40.756099],
#               u'street': u'1 Avenue',
#               u'zipcode': u'10022'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 6, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2013, 6, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 12, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2012, 7, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 2, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41191348'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f551b'),
#  u'address': {u'building': u'14',
#               u'coord': [-73.9778118, 40.7561728],
#               u'street': u'East   47 Street',
#               u'zipcode': u'10017'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 5, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 5, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 12, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2011, 12, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 6}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41191355'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f551c'),
#  u'address': {u'building': u'136',
#               u'coord': [-74.00109499999999, 40.730751],
#               u'street': u'West    3 Street',
#               u'zipcode': u'10012'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 12, 16, 0, 0),
#               u'grade': u'B',
#               u'score': 17},
#              {u'date': datetime.datetime(2013, 7, 8, 0, 0),
#               u'grade': u'B',
#               u'score': 23},
#              {u'date': datetime.datetime(2012, 7, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41191377'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f55e3'),
#  u'address': {u'building': u'2726',
#               u'coord': [-73.96758659999999, 40.7998912],
#               u'street': u'Broadway',
#               u'zipcode': u'10025'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 9, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 9, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 4, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2011, 11, 7, 0, 0),
#               u'grade': u'C',
#               u'score': 50}],
#  u'name': u'Mcdonalds',
#  u'restaurant_id': u'41211622'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f55fd'),
#  u'address': {u'building': u'1997',
#               u'coord': [-73.94265100000001, 40.793812],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 15, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 8, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 3, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2012, 2, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2011, 10, 12, 0, 0),
#               u'grade': u'C',
#               u'score': 37}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41214446'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f5728'),
#  u'address': {u'building': u'3869',
#               u'coord': [-73.9186927, 40.8641934],
#               u'street': u'10 Avenue',
#               u'zipcode': u'10034'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2014, 1, 10, 0, 0),
#               u'grade': u'B',
#               u'score': 14},
#              {u'date': datetime.datetime(2012, 10, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2012, 3, 16, 0, 0),
#               u'grade': u'B',
#               u'score': 26},
#              {u'date': datetime.datetime(2011, 10, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u'Jimbos Hamburger',
#  u'restaurant_id': u'41235974'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f578c'),
#  u'address': {u'building': u'2142',
#               u'coord': [-73.9398709, 40.7986343],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10035'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2014, 3, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 7, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 1, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 1, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41241630'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f578d'),
#  u'address': {u'building': u'3410',
#               u'coord': [-73.953137, 40.822226],
#               u'street': u'Broadway',
#               u'zipcode': u'10031'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 9, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 2, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 5, 31, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2011, 11, 29, 0, 0),
#               u'grade': u'B',
#               u'score': 21}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41241636'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f578e'),
#  u'address': {u'building': u'3549',
#               u'coord': [-73.9505921, 40.826938],
# ...
#              {u'date': datetime.datetime(2012, 1, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2011, 8, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u'Mcdonalds',
#  u'restaurant_id': u'41578610'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f7285'),
#  u'address': {u'building': u'274',
#               u'coord': [-73.9416849, 40.822537],
#               u'street': u'West  145 Street',
#               u'zipcode': u'10039'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 8, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 8, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2012, 4, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2011, 9, 19, 0, 0),
#               u'grade': u'B',
#               u'score': 19}],
#  u'name': u"Jumbo'S Hamburgers",
#  u'restaurant_id': u'41600159'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f737e'),
#  u'address': {u'building': u'422',
#               u'coord': [-73.977963, 40.78410299999999],
#               u'street': u'Amsterdam Avenue',
#               u'zipcode': u'10024'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 23, 0, 0),
#               u'grade': u'Z',
#               u'score': 41},
#              {u'date': datetime.datetime(2014, 6, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 5, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 4, 30, 0, 0),
#               u'grade': u'A',
#               u'score': 4}],
#  u'name': u'Island Burgers & Shakes',
#  u'restaurant_id': u'41609832'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f756e'),
#  u'address': {u'building': u'1695',
#               u'coord': [-73.982942, 40.7636829],
#               u'street': u'Broadway',
#               u'zipcode': u'10019'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 29, 0, 0),
#               u'grade': u'B',
#               u'score': 17},
#              {u'date': datetime.datetime(2013, 9, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 4, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 3, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u"Steak 'N Shake",
#  u'restaurant_id': u'41625305'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f773b'),
#  u'address': {u'building': u'85',
#               u'coord': [-73.9893056, 40.7268043],
#               u'street': u'2 Avenue',
#               u'zipcode': u'10003'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 5, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2013, 4, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 2, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 13}],
#  u'name': u'Bareburger',
#  u'restaurant_id': u'41636189'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f7aee'),
#  u'address': {u'building': u'253',
#               u'coord': [-73.9885482, 40.7570301],
#               u'street': u'West   42 Street',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 3, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 9, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2012, 9, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 2}],
#  u'name': u'Five Guys Burgers And Fries',
#  u'restaurant_id': u'41663207'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f7cf0'),
#  u'address': {u'building': u'636',
#               u'coord': [-73.97067059999999, 40.7592114],
#               u'street': u'Lexington Avenue',
#               u'zipcode': u'10022'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 5, 27, 0, 0),
#               u'grade': u'B',
#               u'score': 21},
#              {u'date': datetime.datetime(2013, 10, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 5, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 9, 11, 0, 0),
#               u'grade': u'B',
#               u'score': 21}],
#  u'name': u"Clarke'S Standard",
#  u'restaurant_id': u'41681170'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f7cf1'),
#  u'address': {u'building': u'870',
#               u'coord': [-73.9898709, 40.73751],
#               u'street': u'Broadway',
#               u'zipcode': u'10003'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2014, 3, 12, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 9, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 3, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 9, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u"Clarke'S Standard",
#  u'restaurant_id': u'41681181'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f7f35'),
#  u'address': {u'building': u'600',
#               u'coord': [-73.9589499, 40.8159927],
#               u'street': u'West  125 Street',
#               u'zipcode': u'10027'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 3, 10, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 7, 31, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 2, 28, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 11, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u'Mcdonalds',
#  u'restaurant_id': u'41696449'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f7ffc'),
#  u'address': {u'building': u'946',
#               u'coord': [-73.98312299999999, 40.7658119],
#               u'street': u'8 Avenue',
#               u'zipcode': u'10019'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2014, 1, 6, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 1, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'41700912'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f80cc'),
#  u'address': {u'building': u'339',
#               u'coord': [-73.990467, 40.759482],
#               u'street': u'West   44 Street',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 30, 0, 0),
#               u'grade': u'Z',
#               u'score': 25},
#              {u'date': datetime.datetime(2014, 5, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 2, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'Smokey Burger Organic',
#  u'restaurant_id': u'41704341'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f84bc'),
#  u'address': {u'building': u'33',
#               u'coord': [-73.997939, 40.733153],
#               u'street': u'West    8 Street',
#               u'zipcode': u'10011'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 2, 19, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2013, 6, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u'Burger Joint',
#  u'restaurant_id': u'50000045'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f863e'),
#  u'address': {u'building': u'366',
#               u'coord': [-73.990357, 40.760558],
#               u'street': u'West   46 Street',
#               u'zipcode': u'10036'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 29, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2013, 10, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u'Bareburger',
#  u'restaurant_id': u'50000763'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f86d6'),
#  u'address': {u'building': u'1681',
#               u'coord': [-73.94909299999999, 40.777772],
#               u'street': u'1 Avenue',
#               u'zipcode': u'10128'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 1, 0, 0),
#               u'grade': u'Z',
#               u'score': 17},
#              {u'date': datetime.datetime(2013, 10, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u'Bareburger',
#  u'restaurant_id': u'50000999'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f872f'),
#  u'address': {u'building': u'509',
#               u'coord': [-73.9776461, 40.7458025],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10016'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 9, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u'Fatburger',
#  u'restaurant_id': u'50001137'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f8736'),
#  u'address': {u'building': u'148',
#               u'coord': [-73.94779199999999, 40.808428],
#               u'street': u'West  125 Street',
#               u'zipcode': u'10027'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2013, 8, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u"Mcdonald'S",
#  u'restaurant_id': u'50001148'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f8a8c'),
#  u'address': {u'building': u'361',
#               u'coord': [-74.0062401, 40.7397546],
#               u'street': u'6 Avenue',
#               u'zipcode': u'10014'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 22, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2014, 7, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2014, 6, 13, 0, 0),
#               u'grade': u'P',
#               u'score': 10},
#              {u'date': datetime.datetime(2013, 11, 8, 0, 0),
#               u'grade': u'B',
#               u'score': 23}],
#  u'name': u'Joy Burger Bar',
#  u'restaurant_id': u'50002603'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f9169'),
#  u'address': {u'building': u'2121',
#               u'coord': [-73.9398334, 40.7976659],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 4, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u"Wendy'S Old Fashioned Hamburgers",
#  u'restaurant_id': u'50008137'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f93f2'),
#  u'address': {u'building': u'20',
#               u'coord': [-73.9926955, 40.7353447],
#               u'street': u'East   14 Street',
#               u'zipcode': u'10003'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 6, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 13}],
#  u'name': u"Wendy'S",
#  u'restaurant_id': u'50010487'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f93f4'),
#  u'address': {u'building': u'92',
#               u'coord': [-73.988252, 40.7322865],
#               u'street': u'3 Avenue',
#               u'zipcode': u'10003'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 15, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u'Blue 9 Burger',
#  u'restaurant_id': u'50010495'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f9596'),
#  u'address': {u'building': u'245',
#               u'coord': [-73.9903118, 40.7542664],
#               u'street': u'West   38 Street',
#               u'zipcode': u'10018'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 26, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u'Black Iron Burger',
#  u'restaurant_id': u'50011926'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f964c'),
#  u'address': {u'building': u'938',
#               u'coord': [-73.98338249999999, 40.7656047],
#               u'street': u'8 Avenue',
#               u'zipcode': u'10019'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 8, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u"Wendy'S",
#  u'restaurant_id': u'50012545'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f997f'),
#  u'address': {u'building': u'155',
#               u'coord': [-74.00609279999999, 40.7099406],
#               u'street': u'William St',
#               u'zipcode': u'10038'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 9, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'Bareburger',
#  u'restaurant_id': u'50015463'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f9b4f'),
#  u'address': {u'building': u'284',
#               u'coord': [-73.94575789999999, 40.807241],
#               u'street': u'Lenox Ave',
#               u'zipcode': u'10027'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u"Jimbo'S",
#  u'restaurant_id': u'50016820'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f9b51'),
#  u'address': {u'building': u'2027',
#               u'coord': [-73.9378643, 40.8034962],
#               u'street': u'Lexington Ave',
#               u'zipcode': u'10035'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 8}],
#  u'name': u"Jimbo'S Hamburger",
#  u'restaurant_id': u'50016822'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f9b57'),
#  u'address': {u'building': u'1567',
#               u'coord': [-73.948689, 40.788436],
#               u'street': u'Lexington Ave',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hamburgers',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 7, 0, 0),
#               u'grade': u'Z',
#               u'score': 26}],
#  u'name': u'Joy Burger Bar',
#  u'restaurant_id': u'50016832'}

# %%
collection.distinct('cuisine')
# Out:
# [u'Bakery',
#  u'Hamburgers',
#  u'Irish',
#  u'American',
#  u'Jewish/Kosher',
#  u'Delicatessen',
#  u'Ice Cream, Gelato, Yogurt, Ices',
#  u'Chinese',
#  u'Chicken',
#  u'Turkish',
#  u'Caribbean',
#  u'Donuts',
#  u'Sandwiches/Salads/Mixed Buffet',
#  u'Bagels/Pretzels',
#  u'Continental',
#  u'Pizza',
#  u'Italian',
#  u'Steak',
#  u'Polish',
#  u'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  u'German',
#  u'French',
#  u'Pizza/Italian',
#  u'Mexican',
#  u'Spanish',
#  u'Caf\xe9/Coffee/Tea',
#  u'Tex-Mex',
#  u'Pancakes/Waffles',
#  u'Soul Food',
#  u'Seafood',
#  u'Hotdogs',
#  u'Greek',
#  u'Not Listed/Not Applicable',
#  u'African',
#  u'Japanese',
#  u'Indian',
#  u'Armenian',
#  u'Thai',
#  u'Chinese/Cuban',
#  u'Mediterranean',
#  u'Korean',
#  u'Bottled beverages, including water, sodas, juices, etc.',
#  u'Russian',
#  u'Eastern European',
#  u'Middle Eastern',
#  u'Asian',
#  u'Ethiopian',
#  u'Vegetarian',
#  u'Barbecue',
#  u'Egyptian',
#  u'English',
#  u'Other',
#  u'Sandwiches',
#  u'Portuguese',
#  u'Indonesian',
#  u'Chinese/Japanese',
#  u'Filipino',
#  u'Juice, Smoothies, Fruit Salads',
#  u'Brazilian',
#  u'Afghan',
#  u'Vietnamese/Cambodian/Malaysia',
#  u'Caf\xc3\xa9/Coffee/Tea',
#  u'Soups & Sandwiches',
#  u'Tapas',
#  u'Moroccan',
#  u'Pakistani',
#  u'Peruvian',
#  u'Bangladeshi',
#  u'Czech',
#  u'Salads',
#  u'Creole',
#  u'Fruits/Vegetables',
#  u'Iranian',
#  u'Cajun',
#  u'Scandinavian',
#  u'Polynesian',
#  u'Soups',
#  u'Australian',
#  u'Hotdogs/Pretzels',
#  u'Southwestern',
#  u'Nuts/Confectionary',
#  u'Hawaiian',
#  u'Creole/Cajun',
#  u'Californian',
#  u'Chilean']

# %% [markdown]
# ### Sub-documents
#
# A valid JSON style "document" can have another JSON document inside it.  To access these, we use the "dot" notation to access them.  For example, to get all the restaurants in a certain zipcode, you would run code as follows:

# %%
from pprint import pprint
cursor = collection.find({'address.zipcode': '10462'}, limit=5)
for c in cursor:
    print(c)
    print("*****************************")
    pprint(c)
    print("*****************************")
    #what's pprint---------pretty print
# Out:
# {u'cuisine': u'Bakery', u'borough': u'Bronx', u'name': u'Morris Park Bake Shop', u'restaurant_id': u'30075445', u'grades': [{u'date': datetime.datetime(2014, 3, 3, 0, 0), u'grade': u'A', u'score': 2}, {u'date': datetime.datetime(2013, 9, 11, 0, 0), u'grade': u'A', u'score': 6}, {u'date': datetime.datetime(2013, 1, 24, 0, 0), u'grade': u'A', u'score': 10}, {u'date': datetime.datetime(2011, 11, 23, 0, 0), u'grade': u'A', u'score': 9}, {u'date': datetime.datetime(2011, 3, 10, 0, 0), u'grade': u'B', u'score': 14}], u'address': {u'building': u'1007', u'street': u'Morris Park Ave', u'zipcode': u'10462', u'coord': [-73.856077, 40.848447]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3bf5')}
# *****************************
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3bf5'),
#  u'address': {u'building': u'1007',
#               u'coord': [-73.856077, 40.848447],
#               u'street': u'Morris Park Ave',
#               u'zipcode': u'10462'},
#  u'borough': u'Bronx',
#  u'cuisine': u'Bakery',
#  u'grades': [{u'date': datetime.datetime(2014, 3, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 2},
#              {u'date': datetime.datetime(2013, 9, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 6},
#              {u'date': datetime.datetime(2013, 1, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2011, 11, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2011, 3, 10, 0, 0),
#               u'grade': u'B',
#               u'score': 14}],
#  u'name': u'Morris Park Bake Shop',
#  u'restaurant_id': u'30075445'}
# *****************************
# {u'cuisine': u'American', u'borough': u'Bronx', u'name': u'The New Starling Athletic Club Of The Bronx', u'restaurant_id': u'40364956', u'grades': [{u'date': datetime.datetime(2014, 12, 18, 0, 0), u'grade': u'A', u'score': 7}, {u'date': datetime.datetime(2014, 5, 1, 0, 0), u'grade': u'B', u'score': 17}, {u'date': datetime.datetime(2013, 3, 14, 0, 0), u'grade': u'A', u'score': 12}, {u'date': datetime.datetime(2012, 9, 20, 0, 0), u'grade': u'A', u'score': 9}, {u'date': datetime.datetime(2012, 2, 8, 0, 0), u'grade': u'B', u'score': 19}], u'address': {u'building': u'2222', u'street': u'Haviland Avenue', u'zipcode': u'10462', u'coord': [-73.84971759999999, 40.8304811]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3c4a')}
# *****************************
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3c4a'),
#  u'address': {u'building': u'2222',
#               u'coord': [-73.84971759999999, 40.8304811],
#               u'street': u'Haviland Avenue',
#               u'zipcode': u'10462'},
#  u'borough': u'Bronx',
#  u'cuisine': u'American',
#  u'grades': [{u'date': datetime.datetime(2014, 12, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2014, 5, 1, 0, 0),
#               u'grade': u'B',
#               u'score': 17},
#              {u'date': datetime.datetime(2013, 3, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 9, 20, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2012, 2, 8, 0, 0),
#               u'grade': u'B',
#               u'score': 19}],
#  u'name': u'The New Starling Athletic Club Of The Bronx',
#  u'restaurant_id': u'40364956'}
# *****************************
# {u'cuisine': u'Caf\xe9/Coffee/Tea', u'borough': u'Bronx', u'name': u"Lulu'S Coffee Shop", u'restaurant_id': u'40366938', u'grades': [{u'date': datetime.datetime(2014, 7, 3, 0, 0), u'grade': u'A', u'score': 12}, {u'date': datetime.datetime(2013, 7, 8, 0, 0), u'grade': u'A', u'score': 9}, {u'date': datetime.datetime(2013, 2, 11, 0, 0), u'grade': u'A', u'score': 11}, {u'date': datetime.datetime(2012, 8, 14, 0, 0), u'grade': u'B', u'score': 14}, {u'date': datetime.datetime(2011, 8, 23, 0, 0), u'grade': u'A', u'score': 12}], u'address': {u'building': u'1191', u'street': u'Castle Hill Avenue', u'zipcode': u'10462', u'coord': [-73.8513114, 40.8316981]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3ca0')}
# *****************************
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3ca0'),
#  u'address': {u'building': u'1191',
#               u'coord': [-73.8513114, 40.8316981],
#               u'street': u'Castle Hill Avenue',
#               u'zipcode': u'10462'},
#  u'borough': u'Bronx',
#  u'cuisine': u'Caf\xe9/Coffee/Tea',
#  u'grades': [{u'date': datetime.datetime(2014, 7, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 7, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 2, 11, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2012, 8, 14, 0, 0),
#               u'grade': u'B',
#               u'score': 14},
#              {u'date': datetime.datetime(2011, 8, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u"Lulu'S Coffee Shop",
#  u'restaurant_id': u'40366938'}
# *****************************
# {u'cuisine': u'American', u'borough': u'Bronx', u'name': u'Bronx Grill', u'restaurant_id': u'40369601', u'grades': [{u'date': datetime.datetime(2014, 10, 14, 0, 0), u'grade': u'A', u'score': 13}, {u'date': datetime.datetime(2014, 4, 8, 0, 0), u'grade': u'A', u'score': 8}, {u'date': datetime.datetime(2013, 11, 4, 0, 0), u'grade': u'C', u'score': 45}, {u'date': datetime.datetime(2013, 5, 23, 0, 0), u'grade': u'A', u'score': 10}, {u'date': datetime.datetime(2012, 10, 18, 0, 0), u'grade': u'B', u'score': 15}, {u'date': datetime.datetime(2012, 10, 5, 0, 0), u'grade': u'P', u'score': 12}, {u'date': datetime.datetime(2012, 5, 14, 0, 0), u'grade': u'A', u'score': 12}, {u'date': datetime.datetime(2011, 12, 21, 0, 0), u'grade': u'A', u'score': 11}], u'address': {u'building': u'2375', u'street': u'East Tremont Avenue', u'zipcode': u'10462', u'coord': [-73.85534559999999, 40.8426433]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3d02')}
# *****************************
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3d02'),
#  u'address': {u'building': u'2375',
#               u'coord': [-73.85534559999999, 40.8426433],
#               u'street': u'East Tremont Avenue',
#               u'zipcode': u'10462'},
#  u'borough': u'Bronx',
#  u'cuisine': u'American',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2014, 4, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2013, 11, 4, 0, 0),
#               u'grade': u'C',
#               u'score': 45},
#              {u'date': datetime.datetime(2013, 5, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 10, 18, 0, 0),
#               u'grade': u'B',
#               u'score': 15},
#              {u'date': datetime.datetime(2012, 10, 5, 0, 0),
#               u'grade': u'P',
#               u'score': 12},
#              {u'date': datetime.datetime(2012, 5, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2011, 12, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 11}],
#  u'name': u'Bronx Grill',
#  u'restaurant_id': u'40369601'}
# *****************************
# {u'cuisine': u'Chinese/Cuban', u'borough': u'Bronx', u'name': u'Sabrosura Restaurant', u'restaurant_id': u'40375136', u'grades': [{u'date': datetime.datetime(2014, 10, 29, 0, 0), u'grade': u'B', u'score': 15}, {u'date': datetime.datetime(2014, 4, 3, 0, 0), u'grade': u'A', u'score': 7}, {u'date': datetime.datetime(2012, 2, 16, 0, 0), u'grade': u'A', u'score': 5}], u'address': {u'building': u'1200', u'street': u'Castle Hill Avenue', u'zipcode': u'10462', u'coord': [-73.8507489, 40.832069]}, u'_id': ObjectId('5bdc53af3a4f0b44814f3d88')}
# *****************************
# {u'_id': ObjectId('5bdc53af3a4f0b44814f3d88'),
#  u'address': {u'building': u'1200',
#               u'coord': [-73.8507489, 40.832069],
#               u'street': u'Castle Hill Avenue',
#               u'zipcode': u'10462'},
#  u'borough': u'Bronx',
#  u'cuisine': u'Chinese/Cuban',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 29, 0, 0),
#               u'grade': u'B',
#               u'score': 15},
#              {u'date': datetime.datetime(2014, 4, 3, 0, 0),
#               u'grade': u'A',
#               u'score': 7},
#              {u'date': datetime.datetime(2012, 2, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'Sabrosura Restaurant',
#  u'restaurant_id': u'40375136'}
# *****************************

# %% [markdown]
# ### Operators
#
# MongoDB has a series of [operators](https://docs.mongodb.com/manual/reference/operator/query/) which allow us to do more sophisticated filters on our queries.  There are too many to go into individually, but we will look at a few important ones.  The specific syntax varies depending on the operator, so it isn't possible to give a general rule, but we will go over a few examples here.  Make sure you check the [documentation](https://docs.mongodb.com/manual/reference/operator/query/) for use on each one.
#
# #### [\$or](https://docs.mongodb.com/manual/reference/operator/query/or/#op._S_or)
#
# Performs a logical **OR** operation on all the key/value pairs in a list, as in the code below:

# %%
# filter = {"$and":[{"borough":"Manhattan"},{"$or": [{"cuisine": "Polynesian"}, {"cuisine": "Hawaiian"}]}]}
filter = {"$or": [{"cuisine": "Polynesian"}, {"cuisine": "Hawaiian"}]}

n=0
for f in collection.find(filter):
    pprint(f)
    n=n+1
    print(n)     #just count
# Out:
# {u'_id': ObjectId('5bdc53af3a4f0b44814f4eca'),
#  u'address': {u'building': u'2241',
#               u'coord': [-73.936071, 40.7955789],
#               u'street': u'1 Avenue',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Polynesian',
#  u'grades': [{u'date': datetime.datetime(2014, 10, 15, 0, 0),
#               u'grade': u'Z',
#               u'score': 22},
#              {u'date': datetime.datetime(2014, 4, 14, 0, 0),
#               u'grade': u'B',
#               u'score': 21},
#              {u'date': datetime.datetime(2013, 2, 21, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2012, 9, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 2, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u'Camaradas El Barrio',
#  u'restaurant_id': u'41024174'}
# 1
# {u'_id': ObjectId('5bdc53af3a4f0b44814f6a89'),
#  u'address': {u'building': u'2245',
#               u'coord': [-73.93600099999999, 40.795675],
#               u'street': u'1 Avenue',
#               u'zipcode': u'10029'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hawaiian',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 17, 0, 0),
#               u'grade': u'C',
#               u'score': 29},
#              {u'date': datetime.datetime(2014, 4, 11, 0, 0),
#               u'grade': u'C',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 10, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 9},
#              {u'date': datetime.datetime(2013, 4, 2, 0, 0),
#               u'grade': u'C',
#               u'score': 41},
#              {u'date': datetime.datetime(2012, 1, 23, 0, 0),
#               u'grade': u'A',
#               u'score': 9}],
#  u'name': u'Makana',
#  u'restaurant_id': u'41509012'}
# 2
# {u'_id': ObjectId('5bdc53af3a4f0b44814f6b0a'),
#  u'address': {u'building': u'360',
#               u'coord': [-73.9854351, 40.7419304],
#               u'street': u'Park Avenue South',
#               u'zipcode': u'10010'},
#  u'borough': u'Manhattan',
#  u'cuisine': u'Hawaiian',
#  u'grades': [{u'date': datetime.datetime(2014, 6, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 11},
#              {u'date': datetime.datetime(2013, 4, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 8, 13, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2011, 8, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 13}],
#  u'name': u'General Assembly',
#  u'restaurant_id': u'41515513'}
# 3
# {u'_id': ObjectId('5bdc53b03a4f0b44814f8952'),
#  u'address': {u'building': u'84',
#               u'coord': [-73.9562856, 40.7139315],
#               u'street': u'Havemeyer Street',
#               u'zipcode': u'11211'},
#  u'borough': u'Brooklyn',
#  u'cuisine': u'Hawaiian',
#  u'grades': [{u'date': datetime.datetime(2014, 11, 18, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2014, 3, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 12}],
#  u'name': u'Onomea',
#  u'restaurant_id': u'50002079'}
# 4

# %% [markdown]
# #### [`$regex`](https://docs.mongodb.com/manual/reference/operator/query/regex/#op._S_regex)
#
# The `$regex` operator searches for a regular expression on a particular field.  Within the filter field, the named field (a key) takes a dict as a value.
#
# For example, to search for all restaurants which start with the word "Pretzel" in the title you can do the following:

# %%
filter = {"name": {"$regex": '^Pretzel'}}
collection.count_documents(filter)
# Out:
# 4

# %% [markdown]
# There are other ways to use regular expressions in PyMongo, you can use the [`re`](https://docs.python.org/3/library/re.html) module in Python.  In Mongo itself, you can use the following syntax: The simplest is to enclose the regular expression inside `/` characters, as in `{"name": /^Pretzel/}`, but that doesn't work properly in PyMongo.
#
# Using the `$regex` operator, find all restaurants which end in "Bar" in the borough of Brooklyn.
#
# HINT: The regex character for the end of a string is `$`

# %%
# YOUR CODE HERE
filter={"$and":[{"name":{"$regex":'bar$'}},{"borough":"Brooklyn"}]}
for i in collection.find(filter):
    pprint(i)
collection.count_documents(filter)
# Out:
# {u'_id': ObjectId('5bdc53af3a4f0b44814f534f'),
#  u'address': {u'building': u'277',
#               u'coord': [-73.9133049, 40.700994],
#               u'street': u'Wyckoff Avenue',
#               u'zipcode': u'11237'},
#  u'borough': u'Brooklyn',
#  u'cuisine': u'Spanish',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 2, 0, 0),
#               u'grade': u'A',
#               u'score': 5},
#              {u'date': datetime.datetime(2013, 10, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 3},
#              {u'date': datetime.datetime(2013, 4, 17, 0, 0),
#               u'grade': u'A',
#               u'score': 10},
#              {u'date': datetime.datetime(2012, 10, 15, 0, 0),
#               u'grade': u'C',
#               u'score': 4},
#              {u'date': datetime.datetime(2012, 2, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 0}],
#  u'name': u'Ambar',
#  u'restaurant_id': u'41154053'}
# {u'_id': ObjectId('5bdc53af3a4f0b44814f6799'),
#  u'address': {u'building': u'644',
#               u'coord': [-73.958815, 40.715044],
#               u'street': u'Driggs Avenue',
#               u'zipcode': u'11211'},
#  u'borough': u'Brooklyn',
#  u'cuisine': u'American',
#  u'grades': [{u'date': datetime.datetime(2014, 9, 25, 0, 0),
#               u'grade': u'A',
#               u'score': 4},
#              {u'date': datetime.datetime(2014, 4, 16, 0, 0),
#               u'grade': u'A',
#               u'score': 8},
#              {u'date': datetime.datetime(2013, 8, 8, 0, 0),
#               u'grade': u'A',
#               u'score': 12},
#              {u'date': datetime.datetime(2013, 1, 31, 0, 0),
#               u'grade': u'A',
#               u'score': 0},
#              {u'date': datetime.datetime(2012, 4, 14, 0, 0),
#               u'grade': u'A',
#               u'score': 7}],
#  u'name': u'Custom Winebar',
#  u'restaurant_id': u'41472755'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f8834'),
#  u'address': {u'building': u'240',
#               u'coord': [-73.9655672, 40.7169149],
#               u'street': u'Kent Avenue',
#               u'zipcode': u'11249'},
#  u'borough': u'Brooklyn',
#  u'cuisine': u'Juice, Smoothies, Fruit Salads',
#  u'grades': [{u'date': datetime.datetime(2014, 6, 4, 0, 0),
#               u'grade': u'A',
#               u'score': 13},
#              {u'date': datetime.datetime(2013, 11, 27, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'Essbar',
#  u'restaurant_id': u'50001598'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f894d'),
#  u'address': {u'building': u'143',
#               u'coord': [-73.957161, 40.711799],
#               u'street': u'Havemeyer Street',
#               u'zipcode': u'11211'},
#  u'borough': u'Brooklyn',
#  u'cuisine': u'American',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 15, 0, 0),
#               u'grade': u'Z',
#               u'score': 16},
#              {u'date': datetime.datetime(2013, 10, 24, 0, 0),
#               u'grade': u'A',
#               u'score': 10}],
#  u'name': u'Jackbar',
#  u'restaurant_id': u'50002070'}
# {u'_id': ObjectId('5bdc53b03a4f0b44814f97b9'),
#  u'address': {u'building': u'93',
#               u'coord': [-73.9584014, 40.7213034],
#               u'street': u'Wythe Ave',
#               u'zipcode': u'11249'},
#  u'borough': u'Brooklyn',
#  u'cuisine': u'Caf\xe9/Coffee/Tea',
#  u'grades': [{u'date': datetime.datetime(2015, 1, 5, 0, 0),
#               u'grade': u'A',
#               u'score': 5}],
#  u'name': u'Matchabar',
#  u'restaurant_id': u'50014030'}
# 5

# %% [markdown]
# #### [`$gt`](https://docs.mongodb.com/manual/reference/operator/query/gt/#op._S_gt)
#
# The `$gt` operator is a comparison between two values where one is greater than the other.
#
# For example, consider this code which finds restaurants which have had a score of more than 15:

# %%
filter = {'grades.score': {'$gt': 12}}   #it should be 15. it maybe a mistake
collection.count_documents(filter)
#*************************
#didn't finish. it ends here
# Out:
# 13980

# %% [markdown]
# Using one of the other comparison operators, find all restaurants which had a grade awarded on the 15 December 2012.  You'll need to create a [`datetime`](https://docs.python.org/2/library/datetime.html#datetime-objects) object in Python.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Organising output
#
# So far, we have seen the two of the arguments in the `find()` and related functions.  The `filter` which allows us to select the criteria for documents in the collection, and the `limit` to limit the amount of results.  You should read the documentation fully about the function in your own time, but for now, we will go over two other arguments which are for organising output: field selection, and sorting.
#
# The field selection or `projection` argument is the argument after the \[optional\] filter, and is either:
#
# * A list of fields to include (plus \_id)
# * A dict of fields with True/False to include
#
# For example, to display only the name of the restaurant:

# %%
filter = {'cuisine': 'Brazilian'}
fields = {'_id': False, 'name': True}
collection.find_one(filter, fields)

# %% [markdown]
# The sort argument is a dict object of field names as keys, and directions.  This can be done either as a named parameter when calling `find()`, or as a function in its own right [`sort()`](https://api.mongodb.com/python/current/api/pymongo/cursor.html#pymongo.cursor.Cursor.sort)
#
# For example, to sort in alphabetical order, consider the following code:

# %%
import pymongo
# The ASCENDING and DESCENDING constants have values of 1 (ASCENDING) and -1 (DESCENDING)
sort = [('name', pymongo.ASCENDING)]
for d in collection.find(filter, projection=fields, sort=sort):
    pprint(d)

# %% [markdown]
# # MongoDB Aggregation Framework
#
# The most common usage for the aggregation framework is to perform group operations such as sum, count or average.  The framework works as a pipeline, with a series of different stages where the data are transformed in each one.
#
# At its simplest, this can be used to obtain output like min, max, count, avg on a collection as follows:

# %%
group = {
    '$group': {
        '_id': None, 
        'size': {'$sum': 1},
        'min': {'$min': '$restaurant_id'},
        'max': {'$max': '$restaurant_id'}
    }
}

cursor = collection.aggregate([group])
for c in cursor:
    print(c)

# %% [markdown]
# Note that it has an `$_id: None` key/value pair in it.  It is compulsory for a `$group` pipeline to have one, and it indicates what it is grouping by.  In this case, we haven't grouped it at all, however it can also be used for more complex output where documents are grouped according to a field.
#
# ### Aggregation example
#
# Consider this example, of finding the breakdown of how many of each type of restaurant there is in the Bronx.  We would need to go through the following stages:
#
# - Identify restaurants which are in the Bronx
# - Group the restaurants by type to get the count
# - Sort the results in a sensible way
#
# The code to perform this query is below:

# %%
# Restrict the results to only establishments in the Bronx.  
# '$match' indicates the stage in the pipeline, and the dictionary is the same as using with find()
match = {
    "$match": {"borough": "Bronx"}
}

# $group indicates the stage in the pipeline
# _id is the field to perform the operation on (like SQL GROUP BY)
# count is the name of the field that the result will be in
# $sum is the counting operation, and the value 1 is how many to count each time
group = {
    '$group': {'_id': '$cuisine', 'count': {'$sum': 1}}
    
}
# $sort indicates the position in the pipeline
# count is the field to sort by, and -1 means to sort in descending order
sort = {
    '$sort': {'count': pymongo.DESCENDING}
}

cursor = collection.aggregate([match, group, sort])
for c in cursor:
    print(c)

# %% [markdown]
# This is a simple query, which shows some of the basic stages of the aggregation pipeline.  It can be improved as follows:
#
# * We can change the name of the `_id` in the output back to `cuisine` using the `$project` stage
# * We can change the order of the output to be sorted in alphabetical order as well
# * We can limit the results to include results only with a count of 20 or more
#
# Implement those stages in the cell below

# %%
# YOUR CODE HERE


pipeline = [match, group] #More code here...
cursor = collection.aggregate(pipeline)
for c in cursor:
    print(c)

# %%
# YOUR CODE HERE FOR sort

pipeline.append(sort)
cursor = collection.aggregate(pipeline)
for c in cursor:
    pprint(c)

# %%
# YOUR CODE HERE FOR `count` > 20

cursor = collection.aggregate(pipeline)
for c in cursor:
    pprint(c)

# %% [markdown]
# ## Challenge
#
# How would you work out the percentage of each type of cuisine out of all selected restaurants?

# %%
# YOUR CODE HERE...

# %% [markdown]
# # Where next?
#
# * Dealing with array data
# * Update, delete, and drop
# * Setting up authentication
# * Sharding databases
